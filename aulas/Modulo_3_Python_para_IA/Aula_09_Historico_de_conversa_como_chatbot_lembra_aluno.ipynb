# %% [markdown]
# # 💻 Notebook do Aluno — Aula 09: Histórico de conversa Como o chatbot lembra
#
# **Disciplina:** Prompt Engineering and Artificial Intelligence
# **Instituição:** FIAP — Ciência da Computação · 2026
# **Professor:** Jorge Luiz Gomes
# **Aula 09/14 — Módulo 3: Python para IA**
# **⏱️ 1h40min**
# **🐍 while · .append() · role assistant**
# **🔁 Andaime 45%**
#
# ---
#
# ## 🎯 Objetivo da aula
#
# Construir um loop de conversa com histórico — o chatbot vai lembrar do que foi dito antes e responder de forma coerente ao longo de vários turnos. Este é o comportamento central de todo assistente de IA do mercado.
#
# ---
#
# ## Como usar este notebook
#
# - Rode as células **na ordem**, de cima para baixo (`Shift+Enter`).
# - Complete apenas as partes marcadas com `___` e `👉 LACUNA`.
# - Não apague o código já pronto — ele é o andaime do lab.
# - Salve sua cópia: **Arquivo > Salvar uma cópia no Drive**.

# %% [markdown]
# ## 📋 Roteiro do Lab
#
# **Lab — Aula 09**
# ### Completar e testar o loop de conversa ★ ★ ★
#
# *Individual · 28 minutos · Google Colab*
#
# 1. Complete as 6 lacunas — roles "system"/"user"/"assistant", True, "sair", break, e a persona na chamada final.
# 2. Execute e converse — inicie o chat e faça pelo menos 4 turnos. No turno 3 ou 4, teste: "O que eu te disse no primeiro turno?" O chatbot deve lembrar.
# 3. Imprima o histórico — adicione print(historico) dentro do loop, logo após adicionar a resposta. Observe a lista crescer a cada turno.
# 4. Desafio — limite de turnos: Modifique o loop para encerrar automaticamente após 5 turnos, mesmo que o usuário não digite "sair". Dica: use um contador turno = 0 que incrementa a cada iteração.
#
# > **🎯 Gabarito das lacunas**
# >
# > Lacuna 1: "system", system
# >
# > Lacuna 2: True
# >
# > Lacuna 3: "sair" (e depois: break)
# >
# > Lacuna 4: "user", entrada
# >
# > Lacuna 5: "assistant", resposta
# >
# > Lacuna 6: qualquer system prompt de sua escolha
#
# > **💡 Dica para o desafio:**
# >
# > adicione turno = 0 antes do while, turno += 1 dentro do loop, e if turno >= 5: break ao final de cada iteração.

# %% [markdown]
# ---
#
# ## 🧩 Notebook Aluno — 45% de lacunas
#
# Complete as lacunas marcadas com `___`.

# %%
# Setup + chamar_llm da Aula 08 (copiar células 1 e 2)
# [cole aqui o setup e a função chamar_llm]

def iniciar_chat(system=""):
    """Loop de conversa com histórico. Complete as lacunas."""
    historico = []

    if system:
        # 👉 LACUNA 1: adicione o system prompt ao histórico
        historico.append({"role": ___, "content": ___})

    print("Chat iniciado. Digite 'sair' para encerrar.\n")

    # 👉 LACUNA 2: escreva o while que mantém o loop rodando
    while ___:

        entrada = input("Você: ")

        # 👉 LACUNA 3: encerre o loop se o usuário digitar "sair"
        if entrada.lower() == ___:
            print("Encerrando. Até logo!")
            ___  # sai do while

        # 👉 LACUNA 4: adicione a mensagem do usuário ao histórico
        historico.append({"role": ___, "content": ___})

        # Chamada à API — não modifique
        resp = _client.chat(model="qwen3.6:27b", messages=historico)
        resposta = resp["message"]["content"]

        # 👉 LACUNA 5: adicione a resposta do assistente ao histórico
        historico.append({"role": ___, "content": ___})

        print(f"Assistente: {resposta}\n")

# 👉 LACUNA 6: chame iniciar_chat com uma persona de sua escolha
iniciar_chat(system=___)

# %% [markdown]
# ---
#
# ## ✍️ Suas anotações
#
# Registre aqui as observações pedidas no roteiro (qualidade dos resultados, comparações e conclusões do grupo).

# %% [markdown]
# ## 📚 Referências da aula
#
# - Livro Russell, S.; Norvig, P. — Inteligência Artificial. 3ª ed. Pearson, 2016. Cap. 2: Agentes com memória — a distinção entre agentes reflexivos simples (stateless) e agentes com estado interno (stateful) é o fundamento conceitual desta aula.
# - Paper Brown, T. et al. — "Language Models are Few-Shot Learners." NeurIPS, 2020. Seção 3: In-context learning — o mecanismo pelo qual o modelo usa o histórico como contexto. arxiv.org/abs/2005.14165
# - Online Anthropic — How Claude uses the messages array (roles: system, user, assistant). docs.anthropic.com/en/api/messages
# - Online OpenAI — Chat completions: the messages parameter. platform.openai.com/docs/guides/chat-completions
# - Online LangChain — ConversationBufferMemory — abstração do histórico de conversa. python.langchain.com
# - Online Python.org — While statements, break and continue. docs.python.org
#
# ---
#
# **Próxima Aula — Aula 10 · Módulo 3** — Prompts com templates e variáveis
#
# Função montar_prompt() com f-string avançada. A terceira peça do chatbot do CKP03.
#
# ---
#
# *Copyright © 2026 Prof. Jorge Luiz Gomes · FIAP · Todos os direitos reservados.*
