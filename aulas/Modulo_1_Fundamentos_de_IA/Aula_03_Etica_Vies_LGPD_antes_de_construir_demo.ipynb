# %% [markdown]
# # 🚀 Notebook do Professor (Demo) — Aula 03: Ética, viés e LGPD Antes de construir qualquer coisa
#
# **Disciplina:** Prompt Engineering and Artificial Intelligence
# **Instituição:** FIAP — Ciência da Computação · 2026
# **Professor:** Jorge Luiz Gomes
# **Aula 03/14 — Módulo 1: Fundamentos de IA · CKP01**
# **⏱️ 1h40min**
# **🔒 Sem código — análise crítica**
# **🏁 CKP01 publicado hoje**
#
# ---
#
# ## Como usar este notebook
#
# - Cada célula corresponde a um slide de código da aula (a ordem é a da apresentação).
# - Rode ao vivo enquanto explica o slide correspondente.
# - A última seção traz o lab do aluno com o gabarito das lacunas.

# %% [markdown]
# ---
#
# # 🗒️ Roteiro de condução
#
# Esta aula **não tem lab em código** — o exercício é conduzido fora do notebook (papel, discussão em grupo ou ferramenta web), conforme o roteiro abaixo. Use este notebook para projetar o enunciado e registrar as conclusões da turma.

# %% [markdown]
# ## 📋 Roteiro do Lab
#
# **Exercício da Aula 03**
# ### Auditoria ética de um sistema de IA real ★ ★ ★
#
# *Grupos de 3–4 · 15 minutos · Apresentação de 2 min por grupo*
#
# 1. Onde pode haver viés? Que grupos podem ser sistematicamente favorecidos ou prejudicados? Que dados de treinamento podem ter causado isso?
# 2. Quais dados são sensíveis? Que dados pessoais o sistema processa? Algum é dado sensível pela LGPD (saúde, raça, religião, biometria)?
# 3. O que violaria a LGPD? Identifique 1 cenário concreto em que o sistema poderia violar a LGPD como hoje é operado.
# 4. Proposta de guarda-chuva: Que 1 mudança técnica ou de processo reduziria os riscos identificados?
#
# > **💡 Dica:**
# >
# > você não precisa saber como o sistema funciona por dentro — faça inferências pelo comportamento observável e pelas notícias sobre o sistema. O raciocínio crítico é mais importante do que precisão técnica aqui.

# %% [markdown]
# ## 🧾 Registro das conclusões da turma
#
# _(anote aqui durante a socialização)_

# %% [markdown]
# ## 📚 Referências da aula
#
# - Livro Russell, S.; Norvig, P. — Inteligência Artificial. 3ª ed. Pearson, 2016. Cap. 26: Fundamentos filosóficos, éticos e futuro da IA.
# - Lei Brasil — Lei Geral de Proteção de Dados (LGPD), Lei 13.709/2018. planalto.gov.br
# - PL Brasil — Projeto de Lei 2338/2023 (Marco Legal da IA). Aprovado pelo Senado Federal em dez/2024. senado.leg.br
# - Caso Air Canada — Tribunal de Resolução Civil da Colúnia Britânica, 2024. Moffatt v. Air Canada. Primeiro caso de responsabilidade por alucinação de chatbot.
# - Caso Amazon — Reuters, 2018. "Amazon scraps secret AI recruiting tool that showed bias against women." reuters.com
# - Online ANPD — Autoridade Nacional de Proteção de Dados. Guias e orientações sobre uso de IA. gov.br/anpd
# - Online Anthropic — Constitutional AI: Harmlessness from AI Feedback. anthropic.com/research
# - Online Samsung — Caso de vazamento de código via ChatGPT, 2023. The Verge, abr/2023.
#
# ---
#
# **Próxima Aula — Aula 04 · Módulo 2** — Anatomia do prompt + primeiro código Python
#
# Os 4 componentes de um prompt eficaz. E as primeiras 8 linhas de Python — cada uma explicada antes de digitar. Ao final da Aula 04 você vai ter feito sua primeira chamada a um LLM via código.
#
# ---
#
# *Copyright © 2026 Prof. Jorge Luiz Gomes · FIAP · Todos os direitos reservados.*
