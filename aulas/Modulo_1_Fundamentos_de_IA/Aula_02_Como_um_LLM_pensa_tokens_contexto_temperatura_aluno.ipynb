# %% [markdown]
# # 💻 Notebook do Aluno — Aula 02: Como um LLM pensa Tokens, contexto e temperatura
#
# **Disciplina:** Prompt Engineering and Artificial Intelligence
# **Instituição:** FIAP — Ciência da Computação · 2026
# **Professor:** Jorge Luiz Gomes
# **Aula 02/14 — Módulo 1: Fundamentos de IA**
# **⏱️ 1h40min**
# **🧠 Sem código — intuição primeiro**
# **🔍 Demo: tokenizador visual**
#
# ---
#
# ## Como usar este notebook
#
# - Rode as células **na ordem**, de cima para baixo (`Shift+Enter`).
# - Complete apenas as partes marcadas com `___` e `👉 LACUNA`.
# - Não apague o código já pronto — ele é o andaime do lab.
# - Salve sua cópia: **Arquivo > Salvar uma cópia no Drive**.

# %% [markdown]
# ## 📋 Roteiro do Lab
#
# **Exercício da Aula 02**
# ### Tokens na prática + prevendo temperatura ★ ★ ★
#
# *Individual · 10 minutos · Usar tokenizer.openai.com*
#
# 1. Parte 1 — Tokenizador (5 min): acesse platform.openai.com/tokenizer e cole os 3 textos abaixo. Anote quantos tokens cada um tem: A) "Prompt Engineering é a arte de conversar com IA de forma estratégica." B) "Prompt Engineering is the art of talking to AI strategically." C) "🤖🧠💻🎯✨🔥📊🚀❤️⭐" (só emojis)
# 2. Parte 2 — Previsão de temperatura (5 min): para cada tarefa abaixo, escreva qual temperatura você usaria e por quê: 1. Extrair o CNPJ de um texto legal 2. Gerar 5 nomes criativos para uma startup de IA 3. Responder "Qual a capital da França?" 4. Escrever um poema sobre tecnologia em estilo livre
#
# > **💡 Gabarito da parte 1:**
# >
# > A) ~13 tokens · B) ~11 tokens (inglês é mais eficiente) · C) surpreenda-se com quantos tokens emojis usam! Dica parte 2: pense se existe "resposta correta" ou se qualquer resposta válida serve.

# %% [markdown]
# ---
#
# ## 🧩 Lab sem código
#
# O lab desta aula é conduzido fora do notebook (papel, discussão ou ferramenta web), conforme o roteiro acima. Use as células abaixo apenas para registrar as respostas do grupo.

# %% [markdown]
# ### Respostas do grupo
#
# _(escreva aqui)_

# %% [markdown]
# ## 📚 Referências da aula
#
# - Livro Russell, S.; Norvig, P. — Inteligência Artificial. 3ª ed. Pearson, 2016. Cap. 2 (agentes e percepção do ambiente) e Cap. 18 (aprendizado a partir de exemplos).
# - Paper Vaswani et al. — "Attention Is All You Need." NeurIPS, 2017. Arquitetura Transformer que fundamenta todo LLM moderno. arxiv.org/abs/1706.03762
# - Paper Brown et al. (OpenAI) — "Language Models are Few-Shot Learners" (GPT-3). NeurIPS, 2020. Fundamento do comportamento in-context. arxiv.org/abs/2005.14165
# - Online OpenAI — Tokenizer visual. platform.openai.com/tokenizer
# - Online Anthropic — "Effective Context Engineering for AI Agents." Set/2025. anthropic.com/engineering
# - Online DAIR.AI — Prompt Engineering Guide: LLM Settings. promptingguide.ai/introduction/settings
#
# ---
#
# **Próxima Aula — Aula 03** — Ética, viés e LGPD — antes de construir qualquer coisa
#
# Alucinações com impacto real, viés algorítmico demonstrado ao vivo, LGPD em 3 regras práticas para quem usa IA. E o CKP01 — que é analítico, sem código e muito mais interessante do que parece.
#
# ---
#
# *Copyright © 2026 Prof. Jorge Luiz Gomes · FIAP · Todos os direitos reservados.*
